# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("gcore_result_all.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = df['comments'].plot()
fig.grid(True)
plt.xlabel('Artical No.')
plt.ylabel('# of Comments')

# %%
fig = df['likes'].plot()
fig.grid(True)
plt.xlabel('Artical No.')
plt.ylabel('# of Likes')

# %%
fig = df.loc[:, ['likes','comments']][::-1].plot()
#fig = dfrev.plot()
fig.grid(True)
plt.xlabel('Artical No.')
plt.ylabel('Count')

# %%
plt.grid()
plt.scatter(df['likes'], df['comments'])
plt.xlabel('# of Likes')
plt.ylabel('# of Comments')

# %%
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X = np.asarray(df['likes'])
Y = np.asarray(df['comments'])
regr.fit(X.reshape(-1,1),Y.reshape(-1,1) )

print('Coefficients: \n', regr.coef_)
print('Intercept: \n', regr.intercept_)

fig = plt.figure()
plt.scatter(X.reshape(-1,1), Y.reshape(-1,1))
plt.plot(X.reshape(-1,1), regr.predict(X.reshape(-1,1)), color='blue',
         linewidth=3)

ax = fig.add_subplot(111)
ax.text(20, 400, r'Comments = Likes * 0.778 + 13.416', fontsize=15)

plt.grid()
plt.xlabel('# of Likes')
plt.ylabel('# of Comments')
# Out:
# ('Coefficients: \n', array([[ 0.77822024]]))
# ('Intercept: \n', array([ 13.41648952]))
# /usr/local/lib/python2.7/site-packages/scipy/linalg/basic.py:1018: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
df['title_len'] = df['title'].str.len()
df['subtitle_len'] = df['subtitle'].str.len()
df
# Out:
#      No.        time  likes  comments                      title  \
# 0      1  2017-04-02     35        32         陌生而熟悉的味道，欢迎来到美国街机厅
# 1      2  2017-03-30     55        16                缅怀素未谋面的郑问老师
# 2      3  2017-03-27     39        23   16-BIT游戏漫谈（4）——魔界村外传：纹章篇
# 3      4  2017-03-18     46        90           悠悠八载街机路：执著、热情与精通
# 4      5  2017-03-17     39        44  三十年相伴相随——聊聊CAPCOM与僵尸的不解情缘
# 5      6  2017-03-13     14        60             火爆狂飙3：速度与对抗的巅峰
# 6      7  2017-03-13    294        80       《凯瑟琳》：性、生活与游戏底层的人性隐喻
# 7      8  2017-03-09     45        33      那会儿想买电脑就是为了跟印第安纳琼斯去冒险
# 8      9  2017-03-06     56        31                  我真的喜欢游戏吗？
# 9     10  2017-03-05     25        37       回顾FC时代的《仁王》——《不动明王传》
# 10    11  2017-03-02     37        30        《塞尔达传说》的这些广告，你都看过么？
# 11    12  2017-02-23     18        20             我和FC：保护那份最初的感动
# 12    13  2017-02-22     47        70         16-BIT游戏漫谈（3）——超级忍
# ...

# %%
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X = np.asarray(df['title_len'])
Y = np.asarray(df['likes'])
regr.fit(X.reshape(-1,1),Y.reshape(-1,1) )

print('Coefficients: {}'.format(regr.coef_[0][0]))
print('Intercept: {}\n'.format(regr.intercept_[0]))

fig = plt.figure()
plt.scatter(X.reshape(-1,1), Y.reshape(-1,1))
plt.plot(X.reshape(-1,1), regr.predict(X.reshape(-1,1)), color='blue',
         linewidth=3)

ax = fig.add_subplot(111)
ax.text(20, 300, r'Likes = Title_len * {0:.2f} + {1:.2f}'.format(regr.coef_[0][0], regr.intercept_[0]), fontsize=15)

plt.grid()
plt.xlabel('Title_len')
plt.ylabel('# of Likes')
plt.title('# of Likes Vs Title_len')
# Out:
# Coefficients: 0.746943193311
# Intercept: 3.07276870693

# %%
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X = np.asarray(df['title_len'])
Y = np.asarray(df['comments'])
regr.fit(X.reshape(-1,1),Y.reshape(-1,1) )

print('Coefficients: {}'.format(regr.coef_[0][0]))
print('Intercept: {}\n'.format(regr.intercept_[0]))

fig = plt.figure()
plt.scatter(X.reshape(-1,1), Y.reshape(-1,1))
plt.plot(X.reshape(-1,1), regr.predict(X.reshape(-1,1)), color='blue',
         linewidth=3)

ax = fig.add_subplot(111)
ax.text(10, 400, r'Comments = Title_len * {0:.2f} + {0:.2f}'.format(regr.coef_[0][0], regr.intercept_[0]), fontsize=15)

plt.grid()
plt.xlabel('Title_len')
plt.ylabel('# of Comments')
plt.title('# of Comments Vs Title_len')
# Out:
# Coefficients: 0.631896376303
# Intercept: 13.6256900347

# %%
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X = np.asarray(df['subtitle_len'])
Y = np.asarray(df['likes'])
regr.fit(X.reshape(-1,1),Y.reshape(-1,1) )

print('Coefficients: {}'.format(regr.coef_[0][0]))
print('Intercept: {}\n'.format(regr.intercept_[0]))

fig = plt.figure()
plt.scatter(X.reshape(-1,1), Y.reshape(-1,1))
plt.plot(X.reshape(-1,1), regr.predict(X.reshape(-1,1)), color='blue',
         linewidth=3)

ax = fig.add_subplot(111)
ax.text(20, 300, r'Likes = SubTitle_len * {0:.2f} + {0:.2f}'.format(regr.coef_[0][0], regr.intercept_[0]), fontsize=15)

plt.grid()
plt.xlabel('SubTitle_len')
plt.ylabel('# of Likes')
plt.title('# of Likes Vs SubTitle_len')
# Out:
# Coefficients: -0.113017290307
# Intercept: 43.2025920324

# %%
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X = np.asarray(df['subtitle_len'])
Y = np.asarray(df['comments'])
regr.fit(X.reshape(-1,1),Y.reshape(-1,1) )

print('Coefficients: {}'.format(regr.coef_[0][0]))
print('Intercept: {}\n'.format(regr.intercept_[0]))

fig = plt.figure()
plt.scatter(X.reshape(-1,1), Y.reshape(-1,1))
plt.plot(X.reshape(-1,1), regr.predict(X.reshape(-1,1)), color='blue',
         linewidth=3)

ax = fig.add_subplot(111)
ax.text(20, 400, r'Comments = SubTitle_len * {0:.2f} + {0:.2f}'.format(regr.coef_[0][0], regr.intercept_[0]), fontsize=15)

plt.grid()
plt.xlabel('SubTitle_len')
plt.ylabel('# of Comments')
plt.title('# of Comments Vs SubTitle_len')
# Out:
# Coefficients: -0.123250617127
# Intercept: 49.5127492917

# %% [markdown]
# ## article number group by years

# %%
df['year'] = df['time'].str[0:4]
g1 = df.groupby(['year'])
g1.groups.keys()
# Out:
# ['2015', '2014', '2017', '2016', '2013']

# %%
g1.count()['time'].tolist()
# Out:
# [33, 14, 33, 72, 64]

# %%
g1.count()['time'].index.tolist()
# Out:
# ['2013', '2014', '2015', '2016', '2017']

# %%
objects = g1.count()['time'].index.tolist()
y_pos = np.arange(len(objects))
performance = g1.count()['time'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of articles')
plt.title('# of Article Vs Year')

# %% [markdown]
# # article number group by month

# %%
df['month'] = df['time'].str[5:7]
g2 = df.groupby(['month'])
g2.groups.keys()
# Out:
# ['02', '03', '01', '06', '07', '04', '05', '08', '09', '12', '11', '10']

# %%
g2.count()['time'].tolist()
# Out:
# [17, 37, 30, 15, 11, 8, 8, 13, 22, 20, 14, 21]

# %%
g2.count()['time'].index.tolist()
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
g2.count()
# Out:
#        No.  time  likes  comments  title  subtitle  title_len  subtitle_len  \
# month
# 01      17    17     17        17     17        17         17            17
# 02      37    37     37        37     37        37         37            37
# 03      30    30     30        30     30        30         30            30
# 04      15    15     15        15     15        15         15            15
# 05      11    11     11        11     11        11         11            11
# 06       8     8      8         8      8         8          8             8
# 07       8     8      8         8      8         8          8             8
# 08      13    13     13        13     13        13         13            13
# 09      22    22     22        22     22        22         22            22
# 10      20    20     20        20     20        20         20            20
# 11      14    14     14        14     14        14         14            14
# ...

# %%
objects = g2.count()['time'].index.tolist()
y_pos = np.arange(len(objects))
performance = g2.count()['time'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of articles')
plt.title('# of Article Vs Month')

# %% [markdown]
# # likes and comments groupby year

# %%
df['year'] = df['time'].str[0:4]
g3 = df.groupby(['year'])
g3sum = g3.sum()

# %%
g3sum['likes']
# Out:
# year
# 2013      74
# 2014      39
# 2015     780
# 2016    3380
# 2017    3347
# Name: likes, dtype: int64

# %%
objects = g3sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
performance = g3sum['likes'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of likes')
plt.title('# of Likes Vs Year')

# %%
articlecount = g1.count()['time'].tolist()

objects = g3sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
articlelikes = g3sum['likes'].tolist()

div = [ai/bi for ai,bi in zip(articlelikes,articlecount)] 
    
plt.bar(y_pos, div, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of likes per article')
plt.title('# of Likes per article Vs Year')

# %%
objects = g3sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
performance = g3sum['comments'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of comments')
plt.title('# of Coments Vs Year')

# %%
objects = g3sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
comments = g3sum['comments'].tolist()
 
objects = g3sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
likes = g3sum['likes'].tolist()

plt.bar(y_pos, likes, align='center', alpha=0.5, width=0.5)
plt.bar(y_pos, comments, align='edge', alpha=0.5, width=0.5)

plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of likes/comments')
plt.title('# of Likes/Coments Vs Year')

# %%
articlecount = g1.count()['time'].tolist()

objects = g3sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
articlecomments = g3sum['comments'].tolist()
 
div = [ai/bi for ai,bi in zip(articlecomments,articlecount)] 
    
plt.bar(y_pos, div, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of comments per article')
plt.title('# of Coments per article Vs Year')

# %%
articlecount = g1.count()['time'].tolist()

objects = g3sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
articlecomments = g3sum['comments'].tolist()

objects = g3sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
articlelikes = g3sum['likes'].tolist()
 
divcomments = [ai/bi for ai,bi in zip(articlecomments,articlecount)] 
divlikes = [ai/bi for ai,bi in zip(articlelikes,articlecount)] 

    
plt.bar(y_pos, divlikes, align='center', alpha=0.5, width=0.5)
plt.bar(y_pos, divcomments, align='edge', alpha=0.5, width=0.5)

plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Year')
plt.ylabel('# of likes/comments per article')
plt.title('# of Likes/Coments per article Vs Year')

# %% [markdown]
# # likes and comment groupby month

# %%
df['month'] = df['time'].str[5:7]
g4 = df.groupby(['month'])
g4sum = g4.sum()

# %%
g4sum
# Out:
#         No.  likes  comments  title_len  subtitle_len
# month
# 01     1372    692       862        737          1151
# 02     2148   1438      2037       1411          1859
# 03     1821   1442      1014       1428          1863
# 04     2087    240       279        589          1269
# 05     1317    333       404        495           793
# 06     1148    229       259        293           556
# 07      996    234       293        369           491
# 08     2125    176       299        572           858
# 09     3808    332       570        892          1978
# 10     3056    503       541        974          1607
# 11     1599    758       859        581          1306
# 12     1959   1243      1411        972          1415

# %%
objects = g4sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
performance = g4sum['likes'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of likes')
plt.title('# of Likes Vs Month')

# %%
articlecount = g2.count()['time'].tolist()
objects = g4sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
articlelikes = g4sum['likes'].tolist()
 
div = [ai/bi for ai,bi in zip(articlelikes,articlecount)] 

plt.bar(y_pos, div, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of likes per article')
plt.title('# of Likes per article Vs Month')

# %%
objects = g4sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
performance = g4sum['comments'].tolist()
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of comments')
plt.title('# of Comments Vs Month')

# %%
objects = g4sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
comments = g4sum['comments'].tolist()

objects = g4sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
likes = g4sum['likes'].tolist()
 
plt.bar(y_pos, likes, align='center', alpha=0.5, width=0.5)
plt.bar(y_pos, comments, align='edge', alpha=0.5, width=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of likes/comments')
plt.title('# of Likes/Comments Vs Month')

# %%
articlecount = g2.count()['time'].tolist()

objects = g4sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
articlecomments = g4sum['comments'].tolist()

div = [ai/bi for ai,bi in zip(articlecomments,articlecount)] 
 
plt.bar(y_pos, div, align='center', alpha=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of comments per article')
plt.title('# of Comments per article Vs Month')

# %%
articlecount = g2.count()['time'].tolist()

objects = g4sum['comments'].index.tolist()
y_pos = np.arange(len(objects))
articlecomments = g4sum['comments'].tolist()

objects = g4sum['likes'].index.tolist()
y_pos = np.arange(len(objects))
articlelikes = g4sum['likes'].tolist()

divcomments = [ai/bi for ai,bi in zip(articlecomments,articlecount)] 
divlikes = [ai/bi for ai,bi in zip(articlelikes,articlecount)] 

plt.bar(y_pos, divlikes, align='center', alpha=0.5, width=0.5) 
plt.bar(y_pos, divcomments, align='edge', alpha=0.5, width=0.5)
plt.grid()

plt.xticks(y_pos, objects)
plt.xlabel('Month')
plt.ylabel('# of likes/comments per article')
plt.title('# of Likes/Comments per article Vs Month')

# %% [markdown]
# # trend of title/subtitle length

# %%
df
# Out:
#      No.        time  likes  comments                      title  \
# 0      1  2017-04-02     35        32         陌生而熟悉的味道，欢迎来到美国街机厅
# 1      2  2017-03-30     55        16                缅怀素未谋面的郑问老师
# 2      3  2017-03-27     39        23   16-BIT游戏漫谈（4）——魔界村外传：纹章篇
# 3      4  2017-03-18     46        90           悠悠八载街机路：执著、热情与精通
# 4      5  2017-03-17     39        44  三十年相伴相随——聊聊CAPCOM与僵尸的不解情缘
# 5      6  2017-03-13     14        60             火爆狂飙3：速度与对抗的巅峰
# 6      7  2017-03-13    294        80       《凯瑟琳》：性、生活与游戏底层的人性隐喻
# 7      8  2017-03-09     45        33      那会儿想买电脑就是为了跟印第安纳琼斯去冒险
# 8      9  2017-03-06     56        31                  我真的喜欢游戏吗？
# 9     10  2017-03-05     25        37       回顾FC时代的《仁王》——《不动明王传》
# 10    11  2017-03-02     37        30        《塞尔达传说》的这些广告，你都看过么？
# 11    12  2017-02-23     18        20             我和FC：保护那份最初的感动
# 12    13  2017-02-22     47        70         16-BIT游戏漫谈（3）——超级忍
# ...

# %%
fig = df.loc[:, ['title_len','subtitle_len']][::-1].plot()

fig.grid(True)
plt.xlabel('Artical No.')
plt.ylabel('Title/Subtitle Length')
plt.title('Trend of Title/Subtitle Length')

# %%
fig = df['subtitle_len'].plot()
fig.grid(True)
plt.xlabel('Artical No.')
plt.ylabel('SubTitle Length')
plt.title('Trend of SubTitle Length')
